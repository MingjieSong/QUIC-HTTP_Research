# %%
import matplotlib.pyplot as plt
import numpy as np
import json
import os
from collections import defaultdict

current_directory = os.getcwd()

quic_tbf = defaultdict(dict)
h1_tbf = defaultdict(dict)
quic_loss = defaultdict(dict)
h1_loss = defaultdict(dict)

for filename in os.listdir(current_directory):
    if filename.endswith('.json'):
        with open(filename, 'r') as file:
            data = json.load(file)
                
            print(f"Processing {filename}...")
            if 'h1_tbf' in filename:
                h1_tbf[filename] = data
            elif 'quic_tbf' in filename:
                quic_tbf[filename] = data
            elif 'h1_netem' in filename:
                h1_loss[filename] = data
            elif 'quic_netem' in filename:
                quic_loss[filename] = data
            file.close()
# Out:
# Processing network_inspect_quic_tbf5g32k70ms_nyu.json...
# Processing network_inspect_quic_tbf50k32k70ms_nyu.json...
# Processing network_inspect_h1_tbf10g32kb70ms_nyu.json...
# Processing network_inspect_quic_tbf1g32k70ms_nyu.json...
# Processing network_inspect_h1_tbf1m32kb70ms_nyu.json...
# Processing network_inspect_quic_netemLoss10_nyu.json...
# Processing network_inspect_quic_tbf0.5m32k70ms_nyu.json...
# Processing network_inspect_h1_netemLoss50_nyu.json...
# Processing network_inspect_h1_tbf5g32kb70ms_nyu.json...
# Processing network_inspect_h1_netemLoss20_nyu.json...
# Processing network_inspect_quic_netemLoss5_nyu.json...
# Processing network_inspect_quic_nyu.json...
# Processing network_inspect_h1_tbf1g32kb70ms_nyu.json...
# Processing network_inspect_h1_tbf50k32kb70ms_nyu.json...
# Processing network_inspect_h1_netemLoss5_nyu.json...
# Processing network_inspect_quic_netemLoss50_nyu.json...
# Processing network_inspect_h1_netemLoss10_nyu.json...
# Processing network_inspect_quic_tbf10g32k70ms_nyu.json...
# Processing network_inspect_quic_tbf1m32k70ms_nyu.json...
# Processing network_inspect_h1_tbf0.5m32kb70ms_nyu.json...
# Processing network_inspect_h1_tbf100k32kb70ms_nyu.json...
# Processing network_inspect_quic_tbf100k32k70ms_nyu.json...
# Processing network_inspect_quic_netemLoss20_nyu.json...
# Processing network_inspect_h1_nyu.json...

# %%
#print(quic_tbf.keys())

tc_order = ['50k', '100k','0.5m','1m','1g', '5g','10g']
quic_throughputs = []
h1_throughputs = []
for size in tc_order:
    for key in quic_tbf.keys():
        if size in key:
            print(size, key)
            quic_throughputs.append(quic_tbf[key][-1]['throughput'])
            break
    for key in h1_tbf.keys():
        if size in key:
            print(size, key)
            h1_throughputs.append(h1_tbf[key][-1]['throughput'])
            break
    print('-------')
# Out:
# 50k network_inspect_quic_tbf50k32k70ms_nyu.json
# 50k network_inspect_h1_tbf50k32kb70ms_nyu.json
# -------
# 100k network_inspect_quic_tbf100k32k70ms_nyu.json
# 100k network_inspect_h1_tbf100k32kb70ms_nyu.json
# -------
# 0.5m network_inspect_quic_tbf0.5m32k70ms_nyu.json
# 0.5m network_inspect_h1_tbf0.5m32kb70ms_nyu.json
# -------
# 1m network_inspect_quic_tbf1m32k70ms_nyu.json
# 1m network_inspect_h1_tbf1m32kb70ms_nyu.json
# -------
# 1g network_inspect_quic_tbf1g32k70ms_nyu.json
# 1g network_inspect_h1_tbf1g32kb70ms_nyu.json
# -------
# 5g network_inspect_quic_tbf5g32k70ms_nyu.json
# 5g network_inspect_h1_tbf5g32kb70ms_nyu.json
# -------
# 10g network_inspect_quic_tbf10g32k70ms_nyu.json
# 10g network_inspect_h1_tbf10g32kb70ms_nyu.json
# -------

# %%
  
# plot lines
plt.plot(tc_order, quic_throughputs, label = "HTTP3")
plt.plot(tc_order, h1_throughputs, label = "HTTP1")

plt.legend()
plt.show()

# %%
loss_percent = ['Loss5', 'Loss10','Loss20','Loss50']
quic_throughputs = []
h1_throughputs = []
for size in loss_percent:
    for key in quic_loss.keys():
        if size in key:
            print(size, key)
            quic_throughputs.append(quic_loss[key][-1]['throughput'])
            break
    for key in h1_loss.keys():
        if size in key:
            print(size, key)
            h1_throughputs.append(h1_loss[key][-1]['throughput'])
            break
    print('-------')
# Out:
# Loss5 network_inspect_quic_netemLoss5_nyu.json
# Loss5 network_inspect_h1_netemLoss50_nyu.json
# -------
# Loss10 network_inspect_quic_netemLoss10_nyu.json
# Loss10 network_inspect_h1_netemLoss10_nyu.json
# -------
# Loss20 network_inspect_quic_netemLoss20_nyu.json
# Loss20 network_inspect_h1_netemLoss20_nyu.json
# -------
# Loss50 network_inspect_quic_netemLoss50_nyu.json
# Loss50 network_inspect_h1_netemLoss50_nyu.json
# -------

# %%
  
# plot lines
plt.plot(loss_percent, quic_throughputs, label = "HTTP3")
plt.plot(loss_percent, h1_throughputs, label = "HTTP1")

plt.legend()
plt.show()

# %%
congestion = "tbf0.5m32k70ms"
intervals = []

url_pre = 'https://10'

quic_intervals = {}
for key in quic_tbf.keys():
    if congestion in key:
        datas = quic_tbf[key]
        for data in datas:
            if 'protocol' in data and data['protocol']=="h3":
                abs_time = data["timing"]["requestTime"]
                quic_intervals[data["url"]]= (((abs_time+data["timing"]["sendStart"]),(abs_time+data["timing"]["receiveHeadersEnd"])))

print(quic_intervals)
h1_intervals = {}

url_pre = 'https://10.10.1.2'
for key in h1_tbf.keys():
    if congestion in key:
        datas = h1_tbf[key]
        for data in datas:
            if "url" in data and url_pre in data['url']:
                abs_time = data["timing"]["requestTime"]
                h1_intervals[data["url"]] = ((abs_time+data["timing"]["sendStart"]),(abs_time+data["timing"]["receiveHeadersEnd"]))
            elif "url" in data and data['url'] in quic_intervals.keys():
                abs_time = data["timing"]["requestTime"] 
                h1_intervals[data["url"]] = ((abs_time+data["timing"]["sendStart"]),(abs_time+data["timing"]["receiveHeadersEnd"]))
# Out:
# {'https://10.10.1.2:4433/': (529624.327652, 529670.816652), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jqueryclientlib.css': (529621.750719, 529621.979719), 'https://10.10.1.2:4433/etc.clientlibs/clientlibs/granite/jquery/granite/csrf.js': (529456.739792, 530751.9297920001), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jqueryclientlib.js': (529456.27146, 530854.92646), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerytablesorterclientlib.css': (529621.726669, 529629.104669), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerytablesorterclientlib.js': (529455.0939219999, 530940.1729219999), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerytouchswipeclientlib.css': (529621.721986, 529630.2239859999), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerytouchswipeclientlib.js': (529454.744523, 535932.487523), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerytouchpunchclientlib.css': (529621.71425, 529631.19725), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerytouchpunchclientlib.js': (529454.4890640001, 537242.088064), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerycustomscrollbarclientlib.css': (529621.733501, 529631.3035009999), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerycustomscrollbarclientlib.js': (529454.224611, 538061.4236110001), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jqueryjscrollpane.css': (529621.730795, 529631.848795), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jqueryjscrollpane.js': (529453.911172, 538779.615172), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jwplayer.css': (529621.7281409999, 529632.286141), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jwplayer.js': (529453.573756, 539034.077756), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jscookie.css': (529621.726452, 529632.895452), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jscookie.js': (529453.247348, 540323.682348), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerytimeago.css': (529621.720846, 529633.4568459999), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jquerytimeago.js': (529452.912928, 541739.491928), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jqueryjpagesclientlib.css': (529621.7201490001, 529634.1301490001), 'https://10.10.1.2:4433/etc/designs/nyuseventy/jqueryjpagesclientlib.js': (529452.639516, 541847.126516), 'https://10.10.1.2:4433/etc/designs/nyuseventy/momentjs.css': (529621.718434, 529634.735434), 'https://10.10.1.2:4433/etc/designs/nyuseventy/momentjs.js': (529452.352083, 542077.794083), 'https://10.10.1.2:4433/etc/designs/nyuseventy/select2.css': (529621.722764, 529635.260764), 'https://10.10.1.2:4433/etc/designs/nyuseventy/select2.js': (529451.981699, 546440.728699), 'https://10.10.1.2:4433/etc/designs/nyuseventy/clientlib.css': (529621.71505, 529636.50305), 'https://10.10.1.2:4433/libs/granite/csrf/token.json': (529640.461073, 530222.059073), 'https://www.google-analytics.com/j/collect?v=1&_v=j100&a=33248192&t=pageview&_s=1&dl=https%3A%2F%2F10.10.1.2%2F&ul=en-us&de=UTF-8&dt=NYU&sd=24-bit&sr=800x600&vp=800x600&je=0&_u=AACAAEABAAAAACAAI~&jid=1497022358&gjid=864497366&cid=1598143871.1686273452&tid=UA-1592055-15&_gid=1615965018.1686273452&_r=1&_slc=1&z=1258381620': (529622.184289, 529671.911289), 'https://10288908.fls.doubleclick.net/activityi;src=10288908;type=retar0;cat=allpa0;ord=1;num=6711349236604;gtm=45He3671;auiddc=595673629.1686273452;u1=%2F;uaa=x86;uab=64;uafvl=Not.A%252FBrand%3B8.0.0.0%7CChromium%3B114.0.5735.90%7CHeadlessChrome%3B114.0.5735.90;uam=;uamb=0;uap=Linux;uapv=5.4.0;uaw=0;~oref=https%3A%2F%2F10.10.1.2%3A4433%2F?': (529622.511992, 529668.356992), 'https://www.google-analytics.com/g/collect?v=2&tid=G-VR2BFTJ92R&gtm=45je3671&_p=33248192&cid=1598143871.1686273452&ul=en-us&sr=800x600&uaa=x86&uab=64&uafvl=Not.A%252FBrand%3B8.0.0.0%7CChromium%3B114.0.5735.90%7CHeadlessChrome%3B114.0.5735.90&uamb=0&uam=&uap=Linux&uapv=5.4.0&uaw=0&ngs=1&_s=1&sid=1686273452&sct=1&seg=1&dl=https%3A%2F%2F10.10.1.2%2F&dt=NYU&en=page_view': (529622.362378, 529668.268378), 'https:// ...

# %%
from matplotlib.lines import Line2D # Imported for legends
from matplotlib import collections  as mc
intervals = []

keys = sorted(h1_intervals.keys())
print(keys)
for k in keys:
    intervals.append(h1_intervals[k])
    
for k in keys:
    k = k.replace(':8000',':4433')
    intervals.append(quic_intervals[k])

keys.extend(keys)


num_intervals = len(intervals)
viridis = plt.cm.get_cmap('viridis', 2)

color_choice = ['r', 'g']
colors = [color_choice[0] if i< num_intervals//2 else color_choice[1] for i in range(num_intervals)]

# Prepare the input data in correct format for LineCollection 
lines = [[(i[0], j), (i[1], j)] for i, j in zip(intervals, range(len(intervals)))]

lc = mc.LineCollection(lines, colors= colors, linewidths=5)
fig, ax = plt.subplots()

ax.add_collection(lc)
ax.margins(0.1)

ax.set_ylabel('common ylabel')


# Adding the legends
def make_proxy(col, scalar_mappable, **kwargs):
    color = col 
    return Line2D([0, 1], [0, 1], color=color, **kwargs)
proxies = [make_proxy(c, lc, linewidth=2) for c in color_choice]
ax.legend(proxies, ['HTTP1', 'HTTP3'])
# Out:
# []

# %%
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np

# Generate some random data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a list of line segments
lines = [[(x[i], y1[i]), (x[i+1], y2[i+1])] for i in range(len(x)-1)]

# Create LineCollection object with the line segments and y-axis values
line_collection = LineCollection(lines, cmap='viridis')

# Create the plot
fig, ax = plt.subplots()
ax.add_collection(line_collection)
ax.autoscale()
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.show()
