# %%
import matplotlib.pyplot as plt
import numpy as np
import json
import os
from collections import defaultdict

current_directory = os.getcwd()

quic = defaultdict(dict)
http1 = defaultdict(dict)
for filename in os.listdir(current_directory):
    if filename.endswith('.json'):
        with open(filename, 'r') as file:
            data = json.load(file)
                
            print(f"Processing {filename}...")
            if 'quic' in filename:
                quic[filename] = data
            else:
                http1[filename] = data
            file.close()
# Out:
# Processing network_inspect_quic_netemLoss20_ucsd.json...
# Processing network_inspect_quic_tbf5g32k70ms_ucsd.json...
# Processing network_inspect_quic_tbf0.5m32k70ms_ucsd.json...
# Processing network_inspect_h1_tbf0.5m32k70ms_ucsd.json...
# Processing network_inspect_quic_tbf1g32k70ms_ucsd.json...
# Processing network_inspect_quic_tbf100k32k70ms_ucsd.json...
# Processing network_inspect_h1_tbf100k32k70ms_ucsd.json...
# Processing network_inspect_quic_netemLoss5_ucsd.json...
# Processing network_inspect_quic_ucsd.json...
# Processing network_inspect_h1_netemLoss10_ucsd.json...
# Processing network_inspect_quic_netemLoss50_ucsd.json...
# Processing network_inspect_quic_tbf1m32k70ms_ucsd.json...
# Processing network_inspect_quic_tbf50k32k70ms_ucsd.json...
# Processing network_inspect_h1_netemLoss20_ucsd.json...
# Processing network_inspect_h1_tbf50k32k70ms_ucsd.json...
# Processing network_inspect_h1_tbf1g32k70ms_ucsd.json...
# Processing network_inspect_h1_tbf5g32k70ms_ucsd.json...
# Processing network_inspect_h1_tbf1m32k70ms_ucsd.json...
# Processing network_inspect_h1_tbf10g32k70ms_ucsd.json...
# Processing network_inspect_h1_ucsd.json...
# Processing network_inspect_quic_tbf10g32k70ms_ucsd.json...
# Processing network_inspect_h1_netemLoss50_ucsd.json...
# Processing network_inspect_h1_netemLoss5_ucsd.json...
# Processing network_inspect_quic_netemLoss10_ucsd.json...

# %%
print(quic)
# Out:
# defaultdict(<class 'dict'>, {'network_inspect_disable_quic_tc5g5g70ms.json': [{'requestId': '4FDAA7D7638773E29A50FA93B97863C9', 'url': 'https://10.10.1.2:8000/', 'timestamp': 261991.076137, 'responseUrl': 'https://10.10.1.2:8000/', 'timing': {'requestTime': 261991.07753, 'proxyStart': -1, 'proxyEnd': -1, 'dnsStart': 0.887, 'dnsEnd': 0.902, 'connectStart': 0.902, 'connectEnd': 3.28, 'sslStart': 1.133, 'sslEnd': 3.271, 'workerStart': -1, 'workerReady': -1, 'workerFetchStart': -1, 'workerRespondWithSettled': -1, 'sendStart': 3.412, 'sendEnd': 3.613, 'pushStart': 0, 'pushEnd': 0, 'receiveHeadersEnd': 5.785}, 'protocol': 'http/1.1'}, {'requestId': '86364.131', 'url': 'https://www.google-analytics.com/g/collect?v=2&tid=G-ZBPHLZYTS4&gtm=45je35v0&_p=1692104752&cid=1955355421.1686005895&ul=en-us&sr=800x600&uaa=x86&uab=64&uafvl=Not.A%252FBrand%3B8.0.0.0%7CChromium%3B114.0.5735.90%7CHeadlessChrome%3B114.0.5735.90&uamb=0&uam=&uap=Linux&uapv=5.4.0&uaw=0&ngs=1&_s=3&sid=1686005895&sct=1&seg=1&dl=https%3A%2F%2F10.10.1.2%2F&dt=University%20of%20California%20San%20Diego&en=user_engagement&_et=68123', 'timestamp': 261991.099746}, {'requestId': '86364.133', 'url': 'https://www.ucsd.edu/_resources/css/vendor/brix_sans.css', 'timestamp': 261991.104394, 'responseUrl': 'https://www.ucsd.edu/_resources/css/vendor/brix_sans.css', 'timing': {'requestTime': 261991.10484, 'proxyStart': -1, 'proxyEnd': -1, 'dnsStart': -1, 'dnsEnd': -1, 'connectStart': -1, 'connectEnd': -1, 'sslStart': -1, 'sslEnd': -1, 'workerStart': -1, 'workerReady': -1, 'workerFetchStart': -1, 'workerRespondWithSettled': -1, 'sendStart': 0.115, 'sendEnd': 0.115, 'pushStart': 0, 'pushEnd': 0, 'receiveHeadersEnd': 1.328}, 'protocol': 'h2'}, {'requestId': '86364.134', 'url': 'https://www.ucsd.edu/_resources/css/vendor/refrigerator_deluxe.css', 'timestamp': 261991.104604, 'responseUrl': 'https://www.ucsd.edu/_resources/css/vendor/refrigerator_deluxe.css', 'timing': {'requestTime': 261991.105339, 'proxyStart': -1, 'proxyEnd': -1, 'dnsStart': -1, 'dnsEnd': -1, 'connectStart': -1, 'connectEnd': -1, 'sslStart': -1, 'sslEnd': -1, 'workerStart': -1, 'workerReady': -1, 'workerFetchStart': -1, 'workerRespondWithSettled': -1, 'sendStart': 0.102, 'sendEnd': 0.102, 'pushStart': 0, 'pushEnd': 0, 'receiveHeadersEnd': 6.074}, 'protocol': 'h2'}, {'requestId': '86364.135', 'url': 'https://www.ucsd.edu/_resources/css/styles.css', 'timestamp': 261991.10479, 'responseUrl': 'https://www.ucsd.edu/_resources/css/styles.css', 'timing': {'requestTime': 261991.105669, 'proxyStart': -1, 'proxyEnd': -1, 'dnsStart': -1, 'dnsEnd': -1, 'connectStart': -1, 'connectEnd': -1, 'sslStart': -1, 'sslEnd': -1, 'workerStart': -1, 'workerReady': -1, 'workerFetchStart': -1, 'workerRespondWithSettled': -1, 'sendStart': 0.082, 'sendEnd': 0.082, 'pushStart': 0, 'pushEnd': 0, 'receiveHeadersEnd': 7.541}, 'protocol': 'h2'}, {'requestId': '86364.136', 'url': 'https://10.10.1.2:8000/_resources/css/custom-img.css', 'timestamp': 261991.104959, 'responseUrl': 'https://10.10.1.2:8000/_resources/css/custom-img.css', 'timing': {'requestTime': 261991.105987, 'proxyStart': -1, 'proxyEnd': -1, 'dnsStart': -1, 'dnsEnd': -1, 'connectStart': -1, 'connectEnd': -1, 'sslStart': -1, 'sslEnd': -1, 'workerStart': -1, 'workerReady': -1, 'workerFetchStart': -1, 'workerRespondWithSettled': -1, 'sendStart': 0.119, 'sendEnd': 0.119, 'pushStart': 0, 'pushEnd': 0, 'receiveHeadersEnd': 8.884}, 'protocol': 'http/1.1'}, {'requestId': '86364.137', 'url': 'https://www.ucsd.edu/_resources/css/custom.css', 'timestamp': 261991.105141, 'responseUrl': 'https://www.ucsd.edu/_resources/css/custom.css', 'timing': {'requestTime': 261991.108627, 'proxyStart': -1, 'proxyEnd': -1, 'dnsStart': -1, 'dnsEnd': -1, 'connectStart': -1, 'connectEnd': -1, 'sslStart': -1, 'sslEnd': -1, 'workerStart': -1, 'workerReady': -1, 'workerFetchStart': -1, 'workerRespondWithSettled': -1, 'sendStart': 0.11, 'sendEnd': 0.11, 'pushStart': 0, 'pushEnd': 0, 'receiveHeadersEnd': 7.855}, 'protocol': 'h2' ...

# %%
from matplotlib.lines import Line2D # Imported for legends
from matplotlib import collections  as mc


intervals = [(1, 2), (1.1, 2.5), (1.2, 4), (1.5, 10), (1.7, 12)]
num_intervals = len(intervals)
viridis = plt.cm.get_cmap('viridis', num_intervals)
colors = np.array([viridis(idx / num_intervals) for idx in range(len(intervals))])

# Prepare the input data in correct format for LineCollection 
lines = [[(i[0], j), (i[1], j)] for i, j in zip(intervals, range(len(intervals)))]

lc = mc.LineCollection(lines, colors= colors, linewidths=2)
fig, ax = plt.subplots()
ax.add_collection(lc)
ax.margins(0.1)
plt.yticks([], [])

# Adding the legends
def make_proxy(col, scalar_mappable, **kwargs):
    color = col 
    return Line2D([0, 1], [0, 1], color=color, **kwargs)
proxies = [make_proxy(c, lc, linewidth=2) for c in colors]
ax.legend(proxies, range(5))

# Adding annotations
for i, x in enumerate(intervals):
    plt.text(x[0], i+0.1, x[0], color=colors[i])
    plt.text(x[1], i+0.1, x[1], color=colors[i])

# %%
x = [1,2,3,4,5]
y = [3,3,3,3,3]
  
# plot lines
plt.plot(x, y, label = "line 1")
plt.plot(y, x, label = "line 2")
plt.plot(x, np.sin(x), label = "curve 1")
plt.plot(x, np.cos(x), label = "curve 2")
plt.legend()
plt.show()
